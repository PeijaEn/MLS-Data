# %%
import numpy as np
import pandas as pd

# %%
goalKeepersCSV = "all_goalkeepers.csv"
allPlayersCSV = "all_players.csv"
allTablesCSV = "all_tables.csv"
eventsCSV = "events.csv"
matchesCSV = "matches.csv"

# %%
keepersDF = pd.read_csv(goalKeepersCSV)
playersDF = pd.read_csv(allPlayersCSV)
tablesDF = pd.read_csv(allTablesCSV)
eventsDF = pd.read_csv(eventsCSV)
matchesDF = pd.read_csv(matchesCSV)
# Out:
# /var/folders/fk/1sb37rnn3_v2gbx8y808lzwm0000gn/T/ipykernel_35906/3936581407.py:5: DtypeWarning: Columns (11,14,50,102,123,125,129,131,133,135,137,139,141,143,145,147,149,157,158,160,161,163,165,167,169,171,173,184,186,187,205,206) have mixed types. Specify dtype option on import or set low_memory=False.
#   matchesDF = pd.read_csv(matchesCSV)

# %%
playersDF.head()
# Out:
#             Player Club POS  GP  GS  MINS   G   A  SHTS  SOG  ...  RdA  \
# 0     Roy Lassiter  TB    F  30  30  2580  27   4    76   49  ...    2
# 1   Raul Diaz Arce  DC    F  28  28  2351  23   2   100   49  ...    2
# 2  Eduardo Hurtado  LA    F  26  26  2323  21   7    87   56  ...    3
# 3            Preki  KC    M  32  32  2880  18  13   140   61  ...    4
# 4    Brian McBride  CLB   F  28  28  2307  17   3    79   44  ...    1
#
#   A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season
# 0    0.14  20  39   70   2   0  64.47  1996     reg
# 1    0.08  32  26   35   6   1  49.00  1996     reg
# 2    0.27  48  26   25   5   0  64.37  1996     reg
# 3    0.41  26  44    7   3   0  43.57  1996     reg
# 4    0.12  21  46   10   0   0  55.70  1996     reg
#
# [5 rows x 28 columns]
